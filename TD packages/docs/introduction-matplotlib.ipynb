# %% [markdown]
# # Une introduction rapide à Matplotlib

# %%
import datetime
print(f"Last updated: {datetime.datetime.now()}")
# Out:
# Last updated: 2023-11-05 11:09:14.529984

# %% [markdown]
# ## Pourquoi matplotlib ?
#
# Matplotlib fait partie de la pile de données standard de Python (pandas, NumPy, matplotlib, Jupyter).
#
# Elle est très bien intégrée à de nombreuses autres bibliothèques Python.
#
# [pandas utilise matplotlib comme backend](https://pandas.pydata.org/docs/user_guide/visualization.html) pour aider à visualiser les données dans les DataFrames.

# %% [markdown]
# ## Que couvre ce notebook ?
#
# Une idée centrale de matplotlib est le concept de "plot" (d'où le nom).
#
# Nous allons donc nous entraîner à faire une série de tracés différents, ce qui est une façon de représenter visuellement des données.
#
# Puisqu'il existe une infinité de façons de créer un graphique, nous allons nous concentrer sur la création et la personnalisation (pour les rendre plus jolis) de quelques types de graphiques courants.

# %% [markdown]
# ## Où puis-je trouver de l'aide ?
#
# Si vous êtes bloqué ou si vous pensez à quelque chose que vous aimeriez faire et qui n'est pas couvert par ce carnet, n'ayez crainte !
#
# Les étapes recommandées sont les suivantes
#
# 1. **Try it** - Puisque matplotlib est très convivial, votre première étape devrait être d'utiliser ce que vous savez et d'essayer de trouver la réponse à votre propre question (se tromper fait partie du processus). En cas de doute, exécutez votre code.
# 2. **Recherchez** - Si essayer par vous-même ne fonctionne pas, puisque quelqu'un d'autre a probablement essayé de faire quelque chose de similaire, essayez de rechercher votre problème dans les endroits suivants (soit via un moteur de recherche, soit directement) :
#     * [matplotlib documentation](https://matplotlib.org/stable/index.html) - le meilleur endroit pour apprendre toutes les vastes fonctionnalités de matplotlib. **Bonus:** Vous pouvez voir une série de [matplotlib cheatsheets sur le site web de matplotlib](https://matplotlib.org/cheatsheets/).
#     * Stack Overflow](https://stackoverflow.com/) - c'est le centre de questions-réponses des développeurs, il est rempli de questions et de réponses sur différents problèmes dans un large éventail de sujets liés au développement de logiciels et il y a de fortes chances qu'il y en ait une en rapport avec votre problème.
#     * [ChatGPT](https://chat.openai.com/) - ChatGPT est très bon pour expliquer le code, mais il peut faire des erreurs. Il est préférable de vérifier le code qu'il écrit avant de l'utiliser. Essayez de demander "Pouvez-vous m'expliquer le code suivant ? {votre code ici}", puis posez des questions complémentaires.
#
# Un exemple de recherche d'une fonctionnalité de matplotlib pourrait être :
#
# > "comment colorer les barres d'un graphique matplotlib"
#
# Une recherche sur Google conduit à cette page de documentation sur le site web de matplotlib : https://matplotlib.org/stable/gallery/lines_bars_and_markers/bar_colors.html
#
# L'étape suivante consiste à lire le message et à voir s'il se rapporte à votre problème. Si c'est le cas, prenez le code/l'information dont vous avez besoin et **réécrivez-le** pour l'adapter à votre propre problème.
#
# 3. **Demander de l'aide** - Si vous avez suivi les 2 étapes précédentes et que vous êtes toujours bloqué, vous pouvez poser votre question sur Stack Overflow ou dans le chat Discord de ZTM. N'oubliez pas d'être aussi précis que possible et de donner des détails sur ce que vous avez essayé.
#
# N'oubliez pas que vous n'avez pas besoin d'apprendre toutes ces fonctions par cœur pour commencer.
#
# Le plus important est de vous demander en permanence "qu'est-ce que j'essaie de visualiser ?".
#
# Commencez par répondre à cette question, puis entraînez-vous à trouver le code qui le fait.
#
# Commençons à visualiser des données !

# %% [markdown]
# ## 0. Importation de matplotlib
#
# Nous allons commencer par importer [`matplotlib.pyplot`] (https://matplotlib.org/stable/tutorials/introductory/pyplot.html).
#
# Pourquoi `pyplot` ?
#
# Parce que `pyplot` est un sous-module qui permet de créer des graphiques interactifs par programme.
#
# `pyplot` est souvent importé sous l'alias `plt`.
#
# **Note:** Dans les anciens notebooks et tutoriels de matplotlib, vous pouvez voir la commande magique `%matplotlib inline`. Cette commande était nécessaire pour visualiser les tracés à l'intérieur d'un carnet, cependant, à partir de 2020, elle n'est plus nécessaire (https://stackoverflow.com/questions/65934740/is-matplotlib-inline-still-needed).

# %%
# Les anciennes versions de Jupyter Notebooks et de matplotlib nécessitaient cette commande magique 
# %matplotlib inline

# Importer matplotlib et matplotlib.pyplot
import matplotlib
import matplotlib.pyplot as plt

print(f"matplotlib version: {matplotlib.__version__}")
# Out:
# matplotlib version: 3.5.0

# %% [markdown]
# ## 1. 2 façons de créer des tracés
#
# Il y a deux façons principales de créer des tracés dans matplotlib.
#
# 1. `matplotlib.pyplot.plot()` - Recommandé pour les tracés simples (par exemple x et y).
# 2. `matplotlib.pyplot.XX` (où XX peut être une des nombreuses méthodes, c'est ce qu'on appelle l'API orientée objet) - Recommandé pour les tracés plus complexes (par exemple [`plt.subplots()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html#matplotlib.pyplot.subplots) pour créer plusieurs tracés sur la même Figure, nous y reviendrons plus tard).
#
# Ces deux méthodes sont encore souvent créées en construisant à partir de `import matplotlib.pyplot as plt` comme base.
#
# Commençons simplement.

# %%
# Traçons des points
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# %% [markdown]
# Quelques petites choses à propos d'un graphique :
# * `x` est l'axe horizontal.
# * `y` est l'axe vertical.
# * Dans un point de données, `x` vient habituellement en premier, par exemple `(3, 4)` serait `(x=3, y=4)`.
# * La même chose se produit dans [`matplotlib.pyplot.plot()`] (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html), `x` vient avant `y`, par exemple `plt.plot(x, y)`.

# %%
# Traçons une courbe
plt.plot(x, y);

# %% [markdown]
# Essayons maintenant d'utiliser la version orientée objet.
#
# Nous allons commencer par créer une figure avec `plt.figure()`.
#
# Puis nous ajouterons un axe avec [`add_subplot`](https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure.add_subplot).

# %%
# Création d'un graphique avec la version orientée objet
fig = plt.figure() # créer une figure
ax = fig.add_subplot() # ajouter un axe 
plt.show()

# %% [markdown]
# Une note sur la terminologie :
# * Une **`Figure`** (par exemple `fig = plt.figure()`) est l'image finale dans matplotlib (et elle peut contenir un ou plusieurs `Axes`), souvent abrégée en `fig`.
# * Les **`Axes`** sont des tracés individuels (par exemple `ax = fig.add_subplot()`), souvent abrégés en `ax`.
#     * Une `Figure` peut contenir un ou plusieurs `Axes`.
# * Les **`Axes`** sont x (horizontal), y (vertical), z (profondeur).
#
# Ajoutons maintenant quelques données à notre graphique précédent.

# %%
# Ajouter des données à notre tracé précédent 
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %% [markdown]
# Mais il y a un moyen plus simple d'utiliser `matplotlib.pyplot` pour nous aider à créer une `Figure` avec de multiples `Axes` potentiels.
#
# Et c'est avec [`plt.subplots()`] (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html).

# %%
# Créer une figure et plusieurs axes potentiels et ajouter des données
fig, ax = plt.subplots()
ax.plot(x, y);

# %%
# C'est de là que vient le nom "orienté objet". 
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ### Un flux de travail rapide pour Matplotlib
#
# Le flux de travail suivant est une pratique standard lors de la création d'un tracé matplotlib :
#
# 0. **Importer matplotlib** - Par exemple, `import matplotlib.pyplot as plt`).
# 1. **Préparer les données** - Elles peuvent provenir d'un ensemble de données existant (analyse de données) ou des résultats d'un modèle d'apprentissage automatique (science des données).
# 2. **Setup the plot** - En d'autres termes, créez la figure et les différents axes.
# 3. **Tracer les données sur les axes** - Envoyez les données pertinentes sur les axes cibles.
# 4. **Cutomize the plot** - Ajoutez un titre, décorez les couleurs, étiquetez chaque axe.
# 5. **Enregistrer (facultatif) et montrer** - Voyez à quoi ressemble votre chef-d'œuvre et enregistrez-le dans un fichier si nécessaire.

# %%
# Un flux de travail matplotlib

# 0. importer et préparer matplotlib
# %matplotlib inline # Pas nécessaire dans les nouvelles versions de Jupyter (par ex. à partir de 2022)
import matplotlib.pyplot as plt

# 1. Préparer les données
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Configurer le graphe (figure et axes)
fig, ax = plt.subplots(figsize=(10,10))

# 3. Tracer les données
ax.plot(x, y)

# 4. Personnaliser le tracé
ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis")

# 5. Sauvegarder et afficher
fig.savefig("../docs/images/simple-plot.png")

# %% [markdown]
# ## 2. Réaliser les types de tracés les plus courants à l'aide des tableaux NumPy
#
# Pour déterminer le type de graphique à utiliser, il faut d'abord avoir une idée des données, puis voir quel type de graphique leur convient le mieux.
#
# Les visualisations Matplotlib sont construites sur des tableaux NumPy. Dans cette section, nous allons donc construire quelques-uns des types de tracés les plus courants en utilisant les tableaux NumPy.
#
# - Tracé linéaire - [`ax.plot()`](https://matplotlib.org/stable/plot_types/basic/plot.html#sphx-glr-plot-types-basic-plot-py) (c'est le tracé par défaut dans Matplotlib)
# - Diagramme de dispersion - [`ax.scatter()`](https://matplotlib.org/stable/plot_types/basic/scatter_plot.html#sphx-glr-plot-types-basic-scatter-plot-py)
# - Diagramme en barres - [`ax.bar()`](https://matplotlib.org/stable/plot_types/basic/bar.html#sphx-glr-plot-types-basic-bar-py)
# - Histogramme - [`ax.hist()`](https://matplotlib.org/stable/plot_types/stats/hist_plot.html#sphx-glr-plot-types-stats-hist-plot-py)
#
# Nous allons voir comment toutes ces méthodes peuvent être créées à partir de [`matplotlob.pyplot.subplots()`] (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html#matplotlib.pyplot.subplots).
#
# **Ressource:** Rappelez-vous que vous pouvez [voir les différents types de tracés de matplotlib](https://matplotlib.org/stable/plot_types/index.html) dans la documentation.
#
# Pour être sûr d'avoir accès à NumPy, nous allons l'importer sous le nom `np`.

# %%
import numpy as np

# %% [markdown]
# ### Création d'un tracé linéaire
#
# Line est le type de visualisation par défaut dans Matplotlib. Habituellement, sauf indication contraire, vos tracés commenceront par des lignes.
#
# Les tracés linéaires sont parfaits pour voir les tendances dans le temps.

# %%
# Creer un tableau
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Le tracé par défaut est la ligne
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %% [markdown]
# ### Création d'un diagramme de dispersion
#
# Les diagrammes de dispersion sont très utiles lorsque vous disposez de nombreux points de données différents et que vous souhaitez voir comment ils interagissent les uns avec les autres sans être reliés entre eux.

# %%
# Nécessité de recréer nos instances de figures et d'axes lorsque nous voulons une nouvelle figure
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %% [markdown]
# ### Création de diagrammes à barres
#
# Les diagrammes en bâtons sont très utiles pour visualiser différentes quantités d'articles à thème similaire.
#
# Par exemple, les ventes d'articles dans un magasin de beurre de noix.
#
# Vous pouvez créer des diagrammes à barres **verticaux** avec [`ax.bar()`](https://matplotlib.org/stable/plot_types/basic/bar.html#sphx-glr-plot-types-basic-bar-py) et des diagrammes à barres **horizontaux** avec [`ax.barh()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html).

# %%
# Vous pouvez faire des tracés à partir d'un dictionnaire
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter Store", ylabel="Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %% [markdown]
# ### Création d'un histogramme
#
# Les histogrammes sont excellents pour montrer la distribution des données.
#
# Par exemple, vous pourriez vouloir montrer la distribution des âges d'une population ou des salaires d'une ville.

# %%
# Fait des données à partir d'une distribution normale
x = np.random.randn(1000) # tire des données d'une distribution normale

fig, ax = plt.subplots()
ax.hist(x);

# %%
x = np.random.random(1000) # données aléatoires provenant d'une distribution aléatoire

fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Création de figures avec plusieurs axes à l'aide de sous-graphes
#
# Les sous-graphes vous permettent de créer plusieurs axes sur la même figure (plusieurs tracés à l'intérieur d'un même graphe).
#
# Les sous-graphes sont utiles parce que vous commencez avec un seul graphe par figure, mais vous pouvez en créer d'autres si nécessaire.
#
# Par exemple, créons un sous-graphe qui montre plusieurs des ensembles de données ci-dessus sur la même figure.
#
# Nous pouvons le faire en créant plusieurs axes avec [`plt.subplots()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html#matplotlib.pyplot.subplots) et en réglant les paramètres `nrows` (nombre de lignes) et `ncols` (nombre de colonnes) pour refléter le nombre d'axes que nous souhaitons.
#
# Les paramètres `nrows` et `ncols` sont multiplicatifs, ce qui signifie que `plt.subplots(nrows=2, ncols=2)` créera `2*2=4` axes au total.
#
# **Ressource:** Vous pouvez voir un [nombre sensationnel d'exemples] (https://matplotlib.org/stable/gallery/index.html#subplots-axes-and-figures) pour la création de Subplots dans la documentation de matplotlib.

# %%
# Option 1 : Créer 4 sous-graphes avec chaque axe ayant son propre nom de variable
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, 
                                             ncols=2, 
                                             figsize=(10, 5))

# Tracer les données sur chaque axe
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Option 2 : Créer 4 sous-graphes avec une seule variable ax
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Indexer la variable ax pour tracer les données
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## 3. Tracer des données directement avec pandas
#
# Matplotlib a également une intégration étroite avec pandas.
#
# Vous pouvez tracer directement à partir d'un DataFrame pandas avec [`DataFrame.plot()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot).
#
# Voyons les tracés suivants directement à partir d'un DataFrame pandas :
#
# * Ligne
# * Scatter
# * Bar
# * Hist
#
# Pour tracer des données avec pandas, nous devons d'abord l'importer en tant que `pd`.

# %%
import pandas as pd

# %% [markdown]
# Il nous faut maintenant des données à vérifier.

# %%
# Importons l'ensemble de données car_sales
car_sales = pd.read_csv("../data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Tracé linéaire à partir d'un DataFrame pandas
#
# Pour comprendre les exemples, je dois souvent les répéter (les coder moi-même) plutôt que de simplement les lire.
#
# Pour commencer à comprendre le tracé avec pandas, recréons la section a des [documents de visualisation pandas Chart] (https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html).

# %%
# Commencer avec des données fictives
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2024', periods=1000))

# Note : ts = short pour les séries temporelles (données dans le temps)
ts
# Out:
# 2024-01-01    1.546210
# 2024-01-02   -1.202375
# 2024-01-03    1.584490
# 2024-01-04   -0.828401
# 2024-01-05   -0.816537
#                 ...
# 2026-09-22   -0.364605
# 2026-09-23   -1.320727
# 2026-09-24    1.055708
# 2026-09-25   -0.041013
# 2026-09-26   -0.202859
# Freq: D, Length: 1000, dtype: float64

# %% [markdown]
# C'est très bien ! Nous avons quelques valeurs aléatoires dans le temps.
#
# Additionnons maintenant les données de manière cumulative avec [`DataFrame.cumsum()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.cumsum.html) (`cumsum` est l'abréviation de cumulative sum ou addition continue d'une chose à la suivante et ainsi de suite).

# %%
# Additionner les valeurs de manière cumulative
ts.cumsum()
# Out:
# 2024-01-01     1.546210
# 2024-01-02     0.343834
# 2024-01-03     1.928325
# 2024-01-04     1.099923
# 2024-01-05     0.283386
#                 ...
# 2026-09-22   -43.565026
# 2026-09-23   -44.885753
# 2026-09-24   -43.830045
# 2026-09-25   -43.871058
# 2026-09-26   -44.073917
# Freq: D, Length: 1000, dtype: float64

# %% [markdown]
# Nous pouvons maintenant visualiser les valeurs en appelant la méthode `plot()` sur le DataFrame et en spécifiant le type de graphique que nous souhaitons avec le paramètre `kind`.
#
# Dans notre cas, il s'agit d'un tracé linéaire, d'où `kind="line"` (c'est la valeur par défaut de la méthode `plot()`).

# %%
# Tracer les valeurs dans le temps avec un tracé linéaire (note : les deux types de tracés renvoient la même chose)
# ts.cumsum().plot() # kind="line" est défini par défaut
ts.cumsum().plot(kind="line") ;

# %% [markdown]
# ### Travailler avec des données réelles
#
# Effectuons quelques manipulations sur notre DataFrame `car_sales`.

# %%
import pandas as pd
# Importation des données relatives aux ventes de voitures 
car_sales = pd.read_csv("../data/car-sales.csv")

# Supprimer les symboles de la colonne prix
car_sales["Price"] = car_sales["Price"].str.replace('$', '', regex=True)
car_sales["Price"] = car_sales["Price"].str.replace(',', '', regex=True)
car_sales["Price"] = car_sales["Price"].apply(lambda x: x[:-3])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Ajouter une colonne de date
car_sales["Sale Date"] = pd.date_range("1/1/2024", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2024-01-01
# 1   Honda    Red          87899      4   5000 2024-01-02
# 2  Toyota   Blue          32549      3   7000 2024-01-03
# 3     BMW  Black          11179      5  22000 2024-01-04
# 4  Nissan  White         213095      4   3500 2024-01-05
# 5  Toyota  Green          99213      4   4500 2024-01-06
# 6   Honda   Blue          45698      4   7500 2024-01-07
# 7   Honda   Blue          54738      4   7000 2024-01-08
# 8  Toyota  White          60000      4   6250 2024-01-09
# 9  Nissan  White          31600      4   9700 2024-01-10

# %%
# Créer une colonne "ventes totales" (ne fonctionne pas, ajoute une chaîne de caractères)
#car_sales["Ventes totales"] = car_sales["Prix"].cumsum()

# Oops... je les veux en int's et non en string
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_sales.plot(x='Sale Date', y='Total Sales');

# %% [markdown]
# ### Diagramme de dispersion à partir d'un DataFrame pandas
#
# Vous pouvez créer des diagrammes de dispersion à partir d'un DataFrame pandas en utilisant le paramètre `kind="scatter"`.
#
# Cependant, vous constaterez souvent que certains diagrammes requièrent certains types de données (par exemple, certains diagrammes requièrent que certaines colonnes soient numériques).

# %%
# Note : Dans les versions précédentes de matplotlib et pandas, avoir la colonne "Price" en tant que chaîne de caractères signifierait
# retournerait une erreur
car_sales["Price"] = car_sales["Price"].astype(str)

# Tracer un diagramme de dispersion
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %% [markdown]
# Le fait d'avoir la colonne `Price` en tant que `int` permet d'obtenir un axe des ordonnées beaucoup plus joli.

# %%
# Convertir le prix en int
car_sales["Price"] = car_sales["Price"].astype(int)

# Tracer un diagramme de dispersion
car_sales.plot(x="Odometer (KM)", y="Price", kind='scatter');

# %% [markdown]
# ### Tracé de barres à partir d'un DataFrame pandas
#
# Voyons comment tracer un graphique à barres à partir d'un DataFrame pandas.
#
# Tout d'abord, nous allons créer quelques données.

# %%
# Créer 10 échantillons aléatoires sur 4 colonnes
x = np.random.rand(10, 4)
x
# Out:
# array([[0.50505202, 0.14315489, 0.44344962, 0.15721969],
#        [0.07125479, 0.73713947, 0.6802345 , 0.73241981],
#        [0.69355275, 0.92791077, 0.7471067 , 0.09118416],
#        [0.80699114, 0.5239938 , 0.80184176, 0.36892152],
#        [0.84575667, 0.6906101 , 0.65825861, 0.05041576],
#        [0.59337143, 0.30248885, 0.12176831, 0.66342277],
#        [0.52504272, 0.82712806, 0.01149157, 0.95668007],
#        [0.28298243, 0.07204106, 0.42904569, 0.09825586],
#        [0.38849397, 0.54607578, 0.48282068, 0.77625176],
#        [0.17963138, 0.19984288, 0.6777668 , 0.23562614]])

# %%
# Transformer les données en DataFrame
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.505052  0.143155  0.443450  0.157220
# 1  0.071255  0.737139  0.680234  0.732420
# 2  0.693553  0.927911  0.747107  0.091184
# 3  0.806991  0.523994  0.801842  0.368922
# 4  0.845757  0.690610  0.658259  0.050416
# 5  0.593371  0.302489  0.121768  0.663423
# 6  0.525043  0.827128  0.011492  0.956680
# 7  0.282982  0.072041  0.429046  0.098256
# 8  0.388494  0.546076  0.482821  0.776252
# 9  0.179631  0.199843  0.677767  0.235626

# %% [markdown]
# Nous pouvons tracer un graphique à barres directement avec la méthode [`bar()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html) sur le DataFrame.

# %%
# Tracer un diagramme à barres
df.plot.bar();

# %% [markdown]
# Nous pouvons également faire la même chose en passant le paramètre `kind="bar"` à `DataFrame.plot()`.

# %%
# Tracer un diagramme à barres avec le paramètre kind
df.plot(kind='bar');

# %% [markdown]
# Essayons un graphique à barres sur le DataFrame `car_sales`.
#
# Cette fois-ci, nous allons spécifier les valeurs des axes `x` et `y`.

# %%
# Tracer un diagramme à barres à partir de car_sales DataFrame
car_sales.plot(x="Make", 
               y="Odometer (KM)", 
               kind="bar");

# %% [markdown]
# ### Tracé d'histogramme à partir d'un DataFrame pandas
#
# Nous pouvons tracer un histogramme à partir de notre DataFrame `car_sales` en utilisant [`DataFrame.plot.hist()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.hist.html) ou `DataFrame.plot(kind="hist")`.
#
# Les histogrammes sont très utiles pour visualiser la distribution ou la dispersion des données.

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %% [markdown]
# En changeant le paramètre `bins`, nous pouvons placer nos données dans différents nombres de collections.
#
# Par exemple, par défaut `bins=10` (10 groupes de données), voyons ce qui se passe si nous le changeons en `bins=20`.

# %%
# Le nombre de cellules par défaut est de 10 
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %% [markdown]
# Pour nous entraîner, créons un histogramme de la colonne `Price`.

# %%
# Créer un histogramme de la colonne Price
car_sales["Price"].plot.hist(bins=10);

# %% [markdown]
# Et pour aller encore plus loin dans la pratique, pourquoi ne pas essayer un autre ensemble de données ?
#
# En l'occurrence, créons des graphiques à partir de l'ensemble de données sur les maladies cardiaques sur lequel nous avons déjà travaillé.

# %%
# Importation de l'ensemble de données sur les maladies cardiaques
heart_disease = pd.read_csv("../data/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Créer un histogramme de la colonne âge
heart_disease["age"].plot.hist(bins=50);

# %% [markdown]
# Qu'est-ce que cela vous apprend sur la diffusion des données relatives aux maladies cardiaques en fonction de l'âge ?

# %% [markdown]
# ### Créer un graphique avec plusieurs axes à partir d'un DataFrame pandas
#
# Nous pouvons également créer une série de tracés (plusieurs axes sur une figure) à partir d'un DataFrame en utilisant le paramètre `subplots=True`.
#
# Tout d'abord, rappelons-nous à quoi ressemblent les données.

# %%
# Inspecter les données
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# Comme toutes nos colonnes ont une valeur numérique, essayons de créer un histogramme pour chacune d'entre elles.

# %%
heart_disease.plot.hist(figsize=(5, 20), 
                        subplots=True);

# %% [markdown]
# Hmmm... est-ce une intrigue très utile ?
#
# Peut-être pas.
#
# Il arrive que l'on visualise trop de choses sur un même graphique et que cela devienne confus.
#
# Il est préférable de commencer par une quantité moindre et d'augmenter progressivement.

# %% [markdown]
# ## 4. Tracer des graphiques plus avancés à partir d'un DataFrame pandas
#
#
# Il est possible d'obtenir des tracés beaucoup plus compliqués et détaillés à partir d'un DataFrame pandas.
#
# Entraînons-nous à utiliser le DataFrame `heart_disease`.
#
# Et à titre d'exemple, effectuons une analyse sur les personnes âgées de plus de 50 ans.
#
# Pour ce faire, commençons par créer un graphique directement à partir de pandas, puis utilisons l'API orientée objet (`plt.subplots()`) pour le développer.

# %%
# Effectuer l'analyse des données sur les patients de plus de 50 ans
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %% [markdown]
# Créons maintenant un diagramme de dispersion directement à partir du DataFrame pandas.
#
# C'est assez facile à faire, mais c'est un peu limité en termes de personnalisation.
#
# Visualisons les taux de cholestérol des patients de plus de 50 ans.
#
# Nous pouvons visualiser quels patients ont ou n'ont pas de maladie cardiaque en colorant les échantillons pour qu'ils soient en ligne avec la colonne `target` (par exemple `0` = pas de maladie cardiaque, `1` = maladie cardiaque).

# %%
# Créer un diagramme de dispersion directement à partir du DataFrame pandas
over_50.plot(kind="scatter",
             x="age", 
             y="chol", 
             c="target", # colorer les points en fonction de la valeur cible
             figsize=(10, 6));

# %% [markdown]
# Nous pouvons recréer le même tracé en utilisant `plt.subplots()` et en passant la variable Axes (`ax`) à la méthode pandas `plot()`.

# %%
# Création d'une figure et d'une instance d'axes
fig, ax = plt.subplots(figsize=(10, 6))

# Tracer les données du DataFrame sur l'objet ax
over_50.plot(kind="scatter", 
             x="age", 
             y="chol", 
             c="target", 
             ax=ax); # définir les axes cibles

# Personnaliser les limites de l'axe des x (pour qu'elles correspondent à nos tranches d'âge cibles)
ax.set_xlim([45, 100]);

# %% [markdown]
# Maintenant, au lieu de tracer directement à partir du DataFrame pandas, nous pouvons faire un tracé un peu plus complet en traçant les données directement sur une instance d'Axes cible.

# %%
# Création d'une figure et d'une instance d'axes
fig, ax = plt.subplots(figsize=(10, 6))

# Tracer les données directement sur les axes intance
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"]) # Colorer les données avec la colonne "cible".

# Personnaliser les paramètres de l'intrigue 
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Configurer la légende
ax.legend(*scatter.legend_elements(), 
          title="Target");

# %% [markdown]
# Et si nous voulions une ligne horizontale qui traverse la moyenne de `heart_disease["chol"]` ?
#
# C'est ce que nous faisons avec la méthode [`Axes.axhline()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axhline.html).

# %%
# Créer le graphe
fig, ax = plt.subplots(figsize=(10, 6))

# Tracer les données
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Personnaliser le tracé
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Ajouter une légende
ax.legend(*scatter.legend_elements(), 
          title="Target")

# Ajouter une ligne moyenne
ax.axhline(over_50["chol"].mean(),
           linestyle="--"); # style de la ligne pour qu'elle soit belle

# %% [markdown]
# ### Tracer plusieurs tracés sur la même figure (ajouter un autre tracé à un tracé existant)
#
# Il arrive que vous souhaitiez visualiser plusieurs caractéristiques d'un ensemble de données ou les résultats d'un modèle sur une même figure.
#
# Vous pouvez y parvenir en ajoutant des données à plusieurs axes sur la même figure.
#
# La méthode [`plt.subplots()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html) vous aide à créer des Figures avec un nombre désiré d'Axes dans une configuration désirée.
#
# En utilisant les paramètres `nrows` (nombre de lignes) et `ncols` (nombre de colonnes), vous pouvez contrôler le nombre d'axes sur la figure.
#
# Par exemple :
# * `nrows=2`, `ncols=1` = 2x1 = une Figure avec 2 Axes
# * `nrows=5`, `ncols=5` = 5x5 = une figure avec 25 axes
#
# Créons un graphique avec 2 axes.
#
# Sur le premier axe (axe 0), nous représenterons les maladies cardiaques en fonction du taux de cholestérol (`chol`).
#
# Sur le deuxième axe (axe 1), nous représenterons les maladies cardiaques en fonction des niveaux de fréquence cardiaque maximale (`thalach`).

# %%
# Configuration du graphique (2 lignes, 1 colonne)
fig, (ax0, ax1) = plt.subplots(nrows=2, # 2 lignes
                               ncols=1, # 1 colonne 
                               sharex=True, # les deux graphiques doivent utiliser le même axe x 
                               figsize=(10, 8))

# ---------- Axe 0 : Maladies cardiaques et taux de cholestérol ----------

# Ajouter des données pour ax0
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"])
# Personnaliser ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")

# Établissement d'une ligne moyenne
ax0.axhline(y=over_50["chol"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# ---------- Axe 1 : Maladies cardiaques et niveaux maximaux de fréquence cardiaque ----------

# Ajouter les données pour ax1
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"])

# Personnaliser ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

# Établissement d'une ligne moyenne
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Titre de la figure
fig.suptitle('Heart Disease Analysis', 
             fontsize=16, 
             fontweight='bold');

# %% [markdown]
# ## 5. Personnaliser vos tracés (les rendre plus jolis)
#
# Si vous n'êtes pas fan du style par défaut de matplotlib, il y a de nombreuses façons de rendre vos tracés plus jolis.
#
# Plus votre graphique est visuellement attrayant, plus il y a de chances que les gens veuillent le regarder.
#
# Cependant, veillez à ne pas exagérer les personnalisations, car elles pourraient nuire à l'information transmise.
#
# Voici quelques-uns des éléments que vous pouvez personnaliser :
#
# **Limites de l'axe** - La plage dans laquelle vos données sont affichées.
# **Couleurs** - Les couleurs qui apparaissent sur le graphique pour représenter les différentes données.
# * Vous pouvez en voir des exemples dans la [documentation de référence des feuilles de style] de Matplotlib (https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html).
# * Vous pouvez modifier la légende d'un axe avec la méthode [`plt.legend()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html#matplotlib.pyplot.legend).
#
# Commençons par explorer les différents styles intégrés à matplotlib.

# %% [markdown]
# ### Personnaliser le style des tracés
#
# Matplotlib est livré avec plusieurs styles intégrés qui sont tous créés avec un thème général.
#
# Vous pouvez voir quels styles sont disponibles en utilisant [`plt.style.available`](https://matplotlib.org/stable/api/style_api.html#matplotlib.style.available).
#
# **Ressources:**
# > Pour voir à quoi ressemblent les styles disponibles, vous pouvez vous référer à la documentation [matplotlib style sheets reference](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html).
# > Pour un guide plus approfondi sur la personnalisation, référez-vous au tutoriel [Customizing Matplotlib with style sheets and rcParams](https://matplotlib.org/stable/tutorials/introductory/customizing.html).

# %%
# Vérifier les styles disponibles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# Avant de modifier le style d'un tracé, rappelons à quoi ressemble le style par défaut.

# %%
# Tracer avant de changer de style
car_sales["Price"].plot();

# %% [markdown]
# Merveilleux !
#
# Maintenant, changeons le style de nos futurs tracés en utilisant la méthode [`plt.style.use(style)`](https://matplotlib.org/stable/api/style_api.html#matplotlib.style.use).
#
# Où le paramètre `style` est l'un des styles matplotlib disponibles.
#
# Et si nous essayions `"seaborn-v0_8-whitegrid"` ([seaborn](https://seaborn.pydata.org/) est une autre bibliothèque de visualisation commune construite au-dessus de matplotlib) ?

# %%
# Changer le style de nos futures parcelles
plt.style.use("seaborn-notebook")

# %%
# Tracer le même graphique que précédemment
car_sales["Price"].plot();

# %% [markdown]
# Merveilleux !
#
# Vous avez remarqué que le style de l'intrigue est légèrement différent ?
#
# Certains styles changent plus que d'autres.
#
# Et si nous essayions `"fivethirtyeight"` ?

# %%
# Modifier le style de tracé
plt.style.use("fivethirtyeight")

# %%
car_sales["Price"].plot();

# %% [markdown]
# Ohhh, c'est une belle figure !
#
# Est-ce que le style est le même pour un autre type de graphique ?
#
# Et si nous essayions un diagramme de dispersion ?

# %%
car_sales.plot(x="Odometer (KM)", 
               y="Price", 
               kind="scatter");

# %% [markdown]
# C'est le cas !
#
# Il semble cependant que nous devions ajuster l'espacement de notre axe des x.
#
# Pourquoi pas un autre style ?
#
# Essayons `"ggplot"`.

# %%
# Modifier le style de tracé
plt.style.use("ggplot")

# %%
car_sales["Price"].plot.hist();

# %% [markdown]
# C'est génial !
#
# Maintenant, comment revenir au style par défaut ?
#
# Indice : avec `"default"`.

# %%
# Modifier le style de tracé pour revenir à la valeur par défaut 
plt.style.use("default")

# %%
car_sales["Price"].plot.hist();

# %% [markdown]
# ### Personnaliser le titre, la légende et les étiquettes des axes
#
# Lorsque vous avez un objet Figure ou Axes de matplotlib, vous pouvez personnaliser de nombreux attributs en utilisant la méthode [`Axes.set()`] (https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set.html).
#
# Par exemple, vous pouvez modifier les attributs suivants
# * `xlabel` - Etiquettes sur l'axe des x.
# * `ylim` - Limites de l'axe des y.
# * `xticks` - Style des x-ticks.
# * Beaucoup plus dans la [documentation] (https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set.html).
#
# Plutôt que d'en parler, pratiquons !
#
# Tout d'abord, nous allons créer des données aléatoires et les placer dans un DataFrame.
#
# Ensuite, nous créerons un graphique à partir de ce DataFrame et nous verrons comment le personnaliser.

# %%
# Créer des données aléatoires
x = np.random.randn(10, 4)
x
# Out:
# array([[-0.13164547, -1.43324442,  0.93265522,  1.06516309],
#        [ 0.51498986,  1.13346954, -0.08130857,  0.9622029 ],
#        [-0.7128564 ,  0.79036398, -0.06630187,  0.01560465],
#        [-2.05427347,  1.9815243 , -0.46171117,  0.31177612],
#        [-0.12499746,  0.54495866, -0.18718921,  0.55790756],
#        [ 1.60077132, -1.57609805,  1.09631257,  1.11362476],
#        [-0.02943547, -0.75938495,  0.37145014, -1.36235286],
#        [-0.29492017,  0.10780661,  1.90260885,  0.8043512 ],
#        [ 1.74441319,  0.10015563,  0.35148197,  2.62820819],
#        [-0.1059852 ,  0.25593135, -0.01016423, -0.38473335]])

# %%
# Transformer les données en DataFrame avec des noms de colonnes simples
df = pd.DataFrame(x, 
                  columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.131645 -1.433244  0.932655  1.065163
# 1  0.514990  1.133470 -0.081309  0.962203
# 2 -0.712856  0.790364 -0.066302  0.015605
# 3 -2.054273  1.981524 -0.461711  0.311776
# 4 -0.124997  0.544959 -0.187189  0.557908
# 5  1.600771 -1.576098  1.096313  1.113625
# 6 -0.029435 -0.759385  0.371450 -1.362353
# 7 -0.294920  0.107807  1.902609  0.804351
# 8  1.744413  0.100156  0.351482  2.628208
# 9 -0.105985  0.255931 -0.010164 -0.384733

# %% [markdown]
# Traçons maintenant les données du DataFrame dans un diagramme à barres.
#
# Cette fois-ci, nous enregistrerons le graphique dans une variable appelée `ax` (abréviation de Axes).

# %%
# Créer un diagramme à barres
ax = df.plot(kind="bar")

# Vérifier le type de la variable ax
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# Excellent !
#
# Nous pouvons voir que le type de notre variable `ax` est `AxesSubplot`, ce qui nous permet d'utiliser toutes les méthodes disponibles dans matplotlib pour `Axes`.
#
# Définissons quelques attributs du graphe avec la méthode [`set()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set.html).
#
# Nous allons changer les attributs `title`, `xlabel` et `ylabel` pour communiquer ce qui est affiché.

# %%
# Recréer l'objet ax
ax = df.plot(kind="bar")

# Définir divers attributs
ax.set(title="Random Number Bar Graph from DataFrame", 
       xlabel="Row number", 
       ylabel="Random number");

# %% [markdown]
# Remarquez que la légende se trouve par défaut dans le coin supérieur gauche, nous pouvons changer cela si nous le souhaitons avec le paramètre `loc` de la méthode [`legend()`] (https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.legend.html).
#
# `loc` peut être défini comme une chaîne de caractères pour refléter l'endroit où la légende doit être placée.
#
# Par défaut, il est fixé à `loc="best"`, ce qui signifie que matplotlib essaiera de trouver le meilleur positionnement possible.
#
# Essayons de le changer pour `"loc="upper right"`.

# %%
# Recréer l'objet ax
ax = df.plot(kind="bar")

# Définir divers attributs
ax.set(title="Random Number Bar Graph from DataFrame", 
       xlabel="Row number", 
       ylabel="Random number")

# Modifier la position de la légende
ax.legend(loc="upper right");

# %% [markdown]
# Joli !
#
# Est-ce que c'est mieux adapté ?
#
# Peut-être pas, mais cela montre qu'il est possible de modifier la position de la légende si nécessaire.

# %% [markdown]
# ### Personnaliser les couleurs des graphiques avec les cartes de couleurs (cmap)
#
# La couleur est l'une des caractéristiques les plus importantes d'un graphique.
#
# Elle permet de distinguer différents types d'informations.
#
# Et avec les bonnes couleurs, les graphiques peuvent être amusants à regarder et à essayer d'en apprendre plus.
#
# Matplotlib fournit de nombreuses options de couleurs grâce à [`matplotlib.colormaps`] (https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.colormaps).
#
# Voyons comment nous pouvons changer les couleurs d'un graphique Matplotlib via le paramètre `cmap` (`cmap` est l'abréviation de `colormaps`).
#
# Nous allons commencer par créer un diagramme de dispersion avec la valeur `cmap` par défaut (`cmap="viridis"`).

# %%
# Configuration de la figure et des axes
fig, ax = plt.subplots(figsize=(10, 6))

# Créer un diagramme de dispersion sans changement de carte (utiliser la carte des couleurs par défaut)
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"],
                     cmap="viridis") # valeur par défaut de la cmap

# Ajouter des attributs au tracé
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.axhline(y=over_50["chol"].mean(), 
           c='b', 
           linestyle='--', 
           label="Average");
ax.legend(*scatter.legend_elements(), 
          title="Target");

# %% [markdown]
# Merveilleux !
#
# Cette parcelle n'a pas l'air trop mal.
#
# Mais que se passe-t-il si nous voulons changer les couleurs ?
#
# Il existe de nombreuses options de paramètres `cmap` disponibles dans la [référence de la carte des couleurs] (https://matplotlib.org/stable/gallery/color/colormap_reference.html).
#
# Et si nous essayions `cmap="winter"` ?
#
# Nous pouvons également changer la couleur de la ligne horizontale en utilisant le paramètre `color` et en lui attribuant une chaîne de caractères de la couleur souhaitée (par exemple, `color="r"` pour rouge).

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Configurer le diagramme de dispersion avec différentes cmap
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"], 
                     cmap="winter") # Changer la valeur de cmap

# Ajouter des attributs au tracé avec une ligne de couleur différente
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
ax.axhline(y=over_50["chol"].mean(), 
           color="r", # Changer la couleur de la ligne en "r" (pour rouge)
           linestyle='--', 
           label="Average");
ax.legend(*scatter.legend_elements(), 
          title="Target");

# %% [markdown]
# Woohoo !
#
# Le premier graphique était joli, mais je pense que je préfère les couleurs de ce nouveau graphique.
#
# Pour en savoir plus sur [choosing colormaps in matplotlib] (https://matplotlib.org/stable/tutorials/colors/colormaps.html), il existe un tutoriel sensationnel et approfondi dans la documentation de matplotlib.

# %% [markdown]
# ### Personnaliser les xlim et ylim
#
# Matplotlib est assez efficace pour définir les plages de valeurs sur l'axe des x et l'axe des y.
#
# Mais comme vous l'avez deviné, vous pouvez les personnaliser pour répondre à vos besoins.
#
# Vous pouvez modifier les plages de valeurs des différents axes en utilisant les paramètres `xlim` et `ylim` à l'intérieur de la méthode `set()`.
#
# Pour nous entraîner, recréons notre graphique à deux axes avec les valeurs par défaut des axes x et y. Nous ajouterons les mises à jour des couleurs dans le graphique à deux axes.
#
# Nous ajouterons également les mises à jour des couleurs de la section précédente.

# %%
# Recréer le graphique à deux axes ci-dessus avec des mises à jour des couleurs 
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 7))

# ---------- Axe 0 ----------
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap="winter")
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Établir une ligne de moyenne
ax0.axhline(y=over_50["chol"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# ---------- Axe 1 ----------
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap="winter")
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Établir une ligne de moyenne
ax1.axhline(y=over_50["thalach"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax1.legend(*scatter.legend_elements(), 
           title="Target")

# Titre de la figure
fig.suptitle("Heart Disease Analysis", 
             fontsize=16, 
             fontweight="bold");

# %% [markdown]
# Recréons maintenant le tracé ci-dessus, mais cette fois-ci, nous allons changer les limites des axes.
#
# Nous pouvons le faire en utilisant [`Axes.set(xlim=[50, 80])`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set.html) ou `Axes.set(ylim=[60, 220])` où les entrées de `xlim` et `ylim` sont une liste d'entiers définissant une plage de valeurs.
#
# Par exemple, `xlim=[50, 80]` fixera les valeurs de l'axe des x pour commencer à `50` et finir à `80`.

# %%
# Recréer le graphique ci-dessus avec des plages d'axes x et y personnalisées
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 7))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol",
        xlim=[50, 80]) # définir les plages de l'axe des x 

# Établir une ligne de moyenne
ax0.axhline(y=over_50["chol"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axe 1, 1 (ligne 1, colonne 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate",
        ylim=[60, 220]) # changer la plage de l'axe des y

# Établir une ligne de moyenne
ax1.axhline(y=over_50["thalach"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax1.legend(*scatter.legend_elements(), 
           title="Target")

# Titre de la figure
fig.suptitle("Heart Disease Analysis", 
             fontsize=16, 
             fontweight="bold");

# %% [markdown]
# Voilà un beau tracé !
#
# Voyons comment le sauvegarder.

# %% [markdown]
# ## 6. Sauvegarde des tracés
#
# Une fois que vous avez obtenu un beau tracé dont vous êtes satisfait, la prochaine étape sera de le partager avec quelqu'un d'autre.
#
# Dans un rapport, un billet de blog, une présentation ou quelque chose de similaire.
#
# Vous pouvez sauvegarder les figures matplotlib avec [`plt.savefig(fname="your_plot_file_name")`] (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html) où `fname` est le nom du fichier cible dans lequel vous souhaitez sauvegarder le tracé.
#
# Avant de sauvegarder notre graphique, recréons-le.

# %%
# Recréer le graphique ci-dessus avec des plages d'axes x et y personnalisées
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 7))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol",
        xlim=[50, 80]) # définir les plages de l'axe des x 

# Établir une ligne de moyenne
ax0.axhline(y=over_50["chol"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axe 1, 1 (ligne 1, colonne 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate",
        ylim=[60, 220]) # changer la plage de l'axe des y

# Établir une ligne de moyenne
ax1.axhline(y=over_50["thalach"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax1.legend(*scatter.legend_elements(), 
           title="Target")

# Titre de la figure
fig.suptitle("Heart Disease Analysis", 
             fontsize=16, 
             fontweight="bold");

# %% [markdown]
# C'est bien !
#
# Nous pouvons sauvegarder nos tracés dans différents types de fichiers.
#
# Et nous pouvons vérifier ces types de fichiers avec `fig.canvas.get_supported_filetypes()`.

# %%
# Vérifier les types de fichiers supportés
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# Les types de fichiers image tels que `jpg` et `png` sont excellents pour les articles de blog et les présentations.
#
# Alors que les types de fichiers `pgf` ou `pdf` sont plus adaptés aux rapports et aux articles.
#
# Un dernier regard sur notre Figure, qui est sauvegardée dans la variable `fig`.

# %%
fig

# %% [markdown]
# C'est magnifique !
#
# Maintenant, enregistrons-le dans un fichier.

# %%
# Sauvegarder le fichier
fig.savefig(fname="../docs/images/heart-disease-analysis.png",
            dpi=100)

# %% [markdown]
# Fichier enregistré !
#
# Essayons de l'afficher.
#
# Nous pouvons le faire avec le code HTML :
#
# ```
# <img src="../images/heart-disease-analysis.png" alt="a plot showing a heart disease analysis comparing the presense of heart disease, cholesterol levels and heart rate on patients over 50/>
# ```
#
# Et en changeant la cellule ci-dessous en markdown.
#
# **Note:** Le graphique étant très visuel, il est important de s'assurer qu'une balise `alt="some_text_here"` est disponible lors de l'affichage de l'image, car cette balise est utilisée pour rendre le graphique plus accessible aux personnes souffrant de déficiences visuelles. Pour en savoir plus sur [l'affichage d'images avec HTML] (https://developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia_and_embedding/Images_in_HTML), voir la documentation de Mozzila.

# %% [markdown]
# <img src="../docs/images/heart-disease-analysis.png" width=900/>

# %% [markdown]
# Enfin, si nous voulons commencer à faire des figures plus nombreuses et différentes, nous pouvons réinitialiser notre variable `fig` en créant un autre graphique.

# %%
# Réinitialise la figure
fig, ax = plt.subplots()

# %% [markdown]
# Si vous créez des tracés et les sauvegardez souvent de cette manière, pour éviter d'écrire trop de code, vous pouvez le mettre dans une fonction.
#
# Une fonction qui suit le flux de travail de Matplotlib.

# %%
# Fonction potentielle de workflow de matplotlib

def plotting_workflow(data) :
    # 1. Manipuler les données
    
    # 2. Créer un graphe
    
    # 3. Tracer les données
    
    # 4. Personnaliser le tracé
    
    # 5. Sauvegarder le tracé
    
    # 6. Retourner le tracé
    
#    Retourner le tracé
# Out:
#   File "/var/folders/7q/5sn_ssd501gcz8xq_xyjv7gm0000gn/T/ipykernel_958/4004415950.py", line 16
#     #    Retourner le tracé
#                            ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## Ressources supplémentaires
#
# Nous avons couvert pas mal de choses ici.
#
# Mais nous n'avons fait qu'effleurer la surface de ce qui est possible avec matplotlib.
#
# Pour en savoir plus, je vous recommande de lire ce qui suit :
#
# * [Matplotlib quick start guide](https://matplotlib.org/stable/tutorials/introductory/quick_start.html) - Essayez de réécrire tout le code de ce guide pour vous familiariser avec lui.
# * [Matplotlib plot types guide](https://matplotlib.org/stable/plot_types/index.html) - A l'intérieur, vous aurez une idée du nombre de types de tracés possibles avec Matplotlib.
# * [Matplotlib lifecycle of a plot guide](https://matplotlib.org/stable/tutorials/introductory/lifecycle.html) - Une démonstration sensationnelle des différentes choses que vous pouvez faire avec un graphe.
